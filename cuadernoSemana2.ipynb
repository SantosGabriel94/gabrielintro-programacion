# %% [markdown]
# <a href="https://colab.research.google.com/github/SantosGabriel94/gabrielintro-programacion/blob/main/cuadernoSemana2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def promedio(N1,N2,N3, N4):
    total = N1 + N2 + N3 + N4 /4
    print(total)

# %% [markdown]
# Pseudocódigo:
# Algoritmo promedio
# 	Leer N1
# 	Leer N2
# 	Leer N3
# 	Leer N4
# 	total = N1 + N2 + N3 + N4/4
# 	Escribir Total
# FinAlgoritmo

# %% [markdown]
# ![sin_titulo.png](data:image/png;base64,...)

# %%
def volumen(largo,ancho,alto):
    if(isinstance(largo,int) and isinstance(ancho,int)and isinstance(alto,int)):
        
        volumen = alto * ancho * largo
        print(volumen)
    else:
        print("Error: NO es un número entero")

# %% [markdown]
# Pseudocódigo:
# Algoritmo calcularVolumenCaja
# 	Leer largo
# 	Leer ancho
# 	Leer alto
# 	Escribir volumen
# 	volumen = alto*ancho*largo
# FinAlgoritmo

# %% [markdown]
# ![volumen.png](data:image/png;base64,...)

# %%
def area(radio):
    
    resultado = 3.14*radio**2
    print(resultado)

# %% [markdown]
# Pseudocódigo:
# Algoritmo circunferencia
# 	Leer p
# 	Leer radio
# 	area <- p * (radio*2*2)
# 	Escribir area
# FinAlgoritmo

# %% [markdown]
# ![area.png](data:image/png;base64,...)

# %%
def votacion(edad):
    if(isinstance(edad,int)):
       while edad>=18:
           
           return "Felicidades puede votar"
       else:
           return "Error: NO puede votar"
    else:
       return "Error: El número no es entero"

# %% [markdown]
# Pseudocódigo:
# Algoritmo votacion
# 	Leer edad
# 	Si edad <= 18 Entonces
# 		Escribir Puede votar
# 	SiNo
# 		Escribir No puede votar
# 	FinSi
# FinAlgoritmo

# %% [markdown]
# ![votacion.png](data:image/png;base64,...)

# %%
def totalPagar(traje):
    if traje >= 2500:
        traje = traje*0.015
        return traje
    else:
        traje = traje*0.08
        return traje

# %% [markdown]
# Pseudocódigo:
# Algoritmo totalPagar
# 	Leer traje
# 	Si traje>=2500 Entonces
# 		traje = (traje * 0.015)
# 	SiNo
# 		traje = (traje * 0.08)
# 	FinSi
# 	Escribir traje
# FinAlgoritmo

# %% [markdown]
# ![totalpagar.png](data:image/png;base64,...)

# %% [markdown]
# ![PRESUPUETOEVENTO.png](data:image/png;base64,...)
